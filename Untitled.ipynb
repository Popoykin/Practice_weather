# %%
import requests
import json
import psycopg2
import time
from psycopg2.extras import execute_batch
from datetime import datetime
from dotenv import load_dotenv
import os
import logging

load_dotenv()

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)

DB_CONFIG = {
  "dbname": os.getenv("dbname"),
  "user": os.getenv("user"),
  "password": os.getenv("password"),
  "host": os.getenv("host"),
  "port": os.getenv("port")
}

API_URL = "https://api.open-meteo.com/v1/forecast"

def get_cities(cur):
    cur.execute("""
      select name, lat, lon
      from raw.city_coords
    """)
    return cur.fetchall()

def fetch_forecast(lat, lon, retries=3):
    params={
       "latitude":lat,
       "longitude":lon,
       "daily":"temperature_2m_max,temperature_2m_min,precipitation_sum"
       }

    for attempt in range(retries):
        try:
            response = requests.get(API_URL, params=params, timeout=10)
            response.raise_for_status()

            data = response.json()

            if "daily" not in data:
                logging.warning(f"Нет daily блока для координат {lat}, {lon}")
                return None
            
            return data["daily"]

        except Exception as e:
            logging.error(f"{lat}, {lon} | попытка {attempt+1} | {e}")
            time.sleep(2 ** attempt)

    return None

def main():
    logging.info(f"START load_forecast")

    forecast_date = datetime.utcnow().date()
    batch_data = []

    try:
        with psycopg2.connect(**DB_CONFIG) as conn:
            with conn.cursor() as cur:
                
              cities = get_cities(cur)
              logging.info(f"Городов: {len(cities)}")

              for name, lat, lon in cities:
                  logging.info(f"Обработка: {name}")

                  daily = fetch_forecast(lat, lon)

                  if daily is None:
                      continue
                  
                  dates = daily["time"]
                  max_temp = daily["temperature_2m_max"]
                  min_temp = daily["temperature_2m_min"]
                  precipitation_forecast = daily["precipitation_sum"]

                  for i in range(len(dates)):
                      batch_data.append((
                          name,
                          dates[i],
                          forecast_date,
                          max_temp[i],
                          min_temp[i],
                          precipitation_forecast[i],
                          datetime.utcnow()
                      ))

                  if not batch_data:
                      raise Exception("Нет данных для загрузки forecast")
        return batch_data
    except Exception as e:
        logging.error(f"CRITICAL: {e}")
        raise

df = main()
# Out:
# 2026-05-03 21:52:00,199 [INFO] START load_forecast
# 2026-05-03 21:52:00,235 [INFO] Городов: 5
# 2026-05-03 21:52:00,236 [INFO] Обработка: Moscow
# 2026-05-03 21:52:04,822 [INFO] Обработка: Samara
# 2026-05-03 21:52:05,414 [INFO] Обработка: Yakutsk
# 2026-05-03 21:52:05,980 [INFO] Обработка: St Petersburg
# 2026-05-03 21:52:06,539 [INFO] Обработка: Vladivostok

# %%
df
# Out:
# [('Moscow',
#   '2026-05-03',
#   datetime.date(2026, 5, 3),
#   21.6,
#   9.0,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Moscow',
#   '2026-05-04',
#   datetime.date(2026, 5, 3),
#   24.5,
#   11.0,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Moscow',
#   '2026-05-05',
#   datetime.date(2026, 5, 3),
#   24.5,
#   14.0,
#   0.3,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Moscow',
#   '2026-05-06',
#   datetime.date(2026, 5, 3),
#   27.6,
#   15.5,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Moscow',
#   '2026-05-07',
#   datetime.date(2026, 5, 3),
#   25.8,
#   13.9,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Moscow',
#   '2026-05-08',
#   datetime.date(2026, 5, 3),
#   19.8,
#   10.2,
#   3.9,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Moscow',
#   '2026-05-09',
#   datetime.date(2026, 5, 3),
#   16.8,
#   7.8,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 4, 822395)),
#  ('Samara',
#   '2026-05-03',
#   datetime.date(2026, 5, 3),
#   13.3,
#   3.8,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Samara',
#   '2026-05-04',
#   datetime.date(2026, 5, 3),
#   18.4,
#   3.6,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Samara',
#   '2026-05-05',
#   datetime.date(2026, 5, 3),
#   23.0,
#   8.6,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Samara',
#   '2026-05-06',
#   datetime.date(2026, 5, 3),
#   24.7,
#   9.6,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Samara',
#   '2026-05-07',
#   datetime.date(2026, 5, 3),
#   25.9,
#   12.4,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Samara',
#   '2026-05-08',
#   datetime.date(2026, 5, 3),
#   27.1,
#   13.7,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Samara',
#   '2026-05-09',
#   datetime.date(2026, 5, 3),
#   21.2,
#   10.4,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 414562)),
#  ('Yakutsk',
#   '2026-05-03',
#   datetime.date(2026, 5, 3),
#   9.1,
#   -1.4,
#   0.2,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('Yakutsk',
#   '2026-05-04',
#   datetime.date(2026, 5, 3),
#   10.0,
#   -1.5,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('Yakutsk',
#   '2026-05-05',
#   datetime.date(2026, 5, 3),
#   11.1,
#   -2.0,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('Yakutsk',
#   '2026-05-06',
#   datetime.date(2026, 5, 3),
#   9.3,
#   -2.7,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('Yakutsk',
#   '2026-05-07',
#   datetime.date(2026, 5, 3),
#   11.6,
#   -1.1,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('Yakutsk',
#   '2026-05-08',
#   datetime.date(2026, 5, 3),
#   13.5,
#   4.1,
#   4.5,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('Yakutsk',
#   '2026-05-09',
#   datetime.date(2026, 5, 3),
#   8.4,
#   -0.9,
#   1.5,
#   datetime.datetime(2026, 5, 3, 17, 52, 5, 980743)),
#  ('St Petersburg',
#   '2026-05-03',
#   datetime.date(2026, 5, 3),
#   16.5,
#   10.7,
#   0.4,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('St Petersburg',
#   '2026-05-04',
#   datetime.date(2026, 5, 3),
#   16.3,
#   8.5,
#   2.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('St Petersburg',
#   '2026-05-05',
#   datetime.date(2026, 5, 3),
#   15.5,
#   7.3,
#   0.3,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('St Petersburg',
#   '2026-05-06',
#   datetime.date(2026, 5, 3),
#   10.8,
#   3.8,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('St Petersburg',
#   '2026-05-07',
#   datetime.date(2026, 5, 3),
#   14.0,
#   3.6,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('St Petersburg',
#   '2026-05-08',
#   datetime.date(2026, 5, 3),
#   15.4,
#   3.1,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('St Petersburg',
#   '2026-05-09',
#   datetime.date(2026, 5, 3),
#   14.4,
#   3.8,
#   1.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 6, 539459)),
#  ('Vladivostok',
#   '2026-05-03',
#   datetime.date(2026, 5, 3),
#   13.1,
#   7.5,
#   3.3,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557)),
#  ('Vladivostok',
#   '2026-05-04',
#   datetime.date(2026, 5, 3),
#   15.9,
#   8.0,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557)),
#  ('Vladivostok',
#   '2026-05-05',
#   datetime.date(2026, 5, 3),
#   14.6,
#   7.9,
#   0.2,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557)),
#  ('Vladivostok',
#   '2026-05-06',
#   datetime.date(2026, 5, 3),
#   14.1,
#   9.1,
#   5.4,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557)),
#  ('Vladivostok',
#   '2026-05-07',
#   datetime.date(2026, 5, 3),
#   17.1,
#   9.3,
#   0.6,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557)),
#  ('Vladivostok',
#   '2026-05-08',
#   datetime.date(2026, 5, 3),
#   17.3,
#   7.8,
#   5.1,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557)),
#  ('Vladivostok',
#   '2026-05-09',
#   datetime.date(2026, 5, 3),
#   16.4,
#   10.5,
#   0.0,
#   datetime.datetime(2026, 5, 3, 17, 52, 7, 182557))]
